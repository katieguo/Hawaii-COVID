# %%
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.dates as mdates
from datetime import datetime

# A list of COVID events and their dates
names = ['First case', 'First Hospitalized', 'Frist Recovered','First Death',
         'School Closed','1st SIP Start', 'First SIP End', 
         '2nd SIP Start', 'School Reopen', '2nd SIP End']

dates = ['2020-02-17', '2020-02-25',
         '2020-02-28', '2020-03-01',
         '2020-03-10', '2020-04-25',
         '2020-05-30', '2020-08-27',
         '2020-09-01', '2020-09-09',
         ]
dates = [datetime.strptime(ii, "%Y-%m-%d") for ii in dates]

# Choose some nice levels
levels = np.tile([-5, 5, -3, 3, -1, 1],
                 int(np.ceil(len(dates)/6)))[:len(dates)]

# Create figure and plot a stem plot with the date
fig, ax = plt.subplots(figsize=(12, 5), constrained_layout=True)
ax.set(title="Hawaii COVID Events and Dates in 2020")

markerline, stemline, baseline = ax.stem(dates, levels,
                                         linefmt="C3-", basefmt="k-",
                                         use_line_collection=True)

plt.setp(markerline, mec="k", mfc="w", zorder=3)

# Shift the markers to the baseline by replacing the y-data by zeros.
markerline.set_ydata(np.zeros(len(dates)))

# annotate lines
vert = np.array(['top', 'bottom'])[(levels > 0).astype(int)]
for d, l, r, va in zip(dates, levels, names, vert):
    ax.annotate(r, xy=(d, l), xytext=(-3, np.sign(l)*3),
                textcoords="offset points", va=va, ha="center")
                  
# format xaxis with 7 day intervals
ax.get_xaxis().set_major_locator(mdates.DayLocator(interval=7))
ax.get_xaxis().set_major_formatter(mdates.DateFormatter("%b %d"))
plt.setp(ax.get_xticklabels(), rotation=30, ha="right")

# remove y axis and spines
ax.get_yaxis().set_visible(False)
for spine in ["left", "top", "right"]:
    ax.spines[spine].set_visible(False)

ax.margins(y=0.1)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.dates as mdates
from datetime import datetime


# A list of COVID events and their dates
names = ['3/5: First emergency\nproclamation issued', 
         '3/6: First case', 
         '3/23: First death;\nNon-essential businesses,\ncity and beach parks close.\nAll city events canceled.\nOahu stay-at-home order begins',
         '3/25: State and Maui County stay-at-home\norders begin; Public gathering\nspaces closed until Apr 30',
         '3/26: Mandatory 14-day quarantine\nfor travelers to Hawaii begins',
         '3/31: First death', 
         '4/1: Mandatory 14-day quarantine\nfor interisland travelers begins', 
       #  'Second death', 
        # 'Third death', 
        # 'Fourth death', 
         '4/13: Total cases surpasses 500,\n9 have died', 
         '4/17: State beaches close;\nDOE announces distance learning\nuntil end of school year', 
       #  'Daily new cases fall to single digits\nand continue for almost 2 months',
         '4/23: Face masks required in all business\nand public transportation in Honolulu',
         '4/25: State extends stay-at-home orders\nand the 14-day quarantine for\ntravelers until May 31',
         '5/5: Safer-at-home orders begin', 
         '5/7: Low-risk facilities reopen', 
         '5/15: Honolulu shopping centers,\nsport fields and courts,\nand drive-in services\nfor religious purposes reopen', 
         '5/16: Honolulu beaches reopen,\nwith social distancing', 
         '5/18: “Safer at Home” changes to\n“Acting with Care”. Medium-risk\nbusinesses can reopen in several weeks',
         '5/23: In-person spiritual services\nresume, with social distancing', 
         '5/31: Stay-at-home orders end', 
         '6/8: All state beaches and some\nstate parks reopen',
         '6/12: Daily cases reach double digits\nfirst time since Apr 18',
         '6/16: Interisland travelers no longer\nrequire self-quarantine',
         '6/19: Gyms, recreation areas, bars,\nand most other places reopen in Honolulu', 
         '6/20: Total cases surpass 800', 
         '6/30: 14-day quarantine for all travelers ends', 
         '7/23: Starts three record-setting days\nof case count: 55,60,73.\nMasks required in Honolulu gyms', 
         '8/1: Out-of-state visitors allowed to avoid\n14-day quarantine with\nnegative test results upon arrival', 
         '8/13: Daily cases of 355 sets new\nrecord; Marking 12+ days\nof 100+ daily new cases', 
         '8/18: Emergency Order 2020-24 Act With Care,\n No Social Gatherings is enacted', 
         '8/26: Surge testing funded. 5000 people\ntested with 277 new cases',
         '8/27: New Stay-at-home order begins; DOE\nextends distance learning until Oct 2.\nSecond stay-at-home order begins',
         '8/31: Deadliest day since COVID with 7 deaths',         
         '9/15: Death rate hits 100',
         '9/24: Four-week-stay-at-home order\nends with a new tiered system\n for reopening']

dates = ['2020-03-05', 
         '2020-03-06',
         '2020-03-23', 
         '2020-03-25',
         '2020-03-26', 
         '2020-03-31',
         '2020-04-01', 
         #'2020-04-02',
         #'2020-04-03',
         #'2020-04-04', 
         '2020-04-13',
         '2020-04-17', 
        # '2020-04-19',
         '2020-04-23',
         '2020-04-25', 
         '2020-05-05',
         '2020-05-07',
         '2020-05-15', 
         '2020-05-16',
         '2020-05-18', 
         '2020-05-23',
         '2020-05-31', 
         '2020-06-08',
         '2020-06-12',
         '2020-06-16', 
         '2020-06-19',
         '2020-06-20', 
         '2020-06-30',
         '2020-07-23', 
         '2020-08-01',
         '2020-08-13',
         '2020-08-18', 
         '2020-08-26',
         '2020-08-27', 
         '2020-08-31',
         '2020-09-15',     
         '2020-09-24',
         ]
dates = [datetime.strptime(ii, "%Y-%m-%d") for ii in dates]

# Choose some nice levels
levels = np.tile([-16, 16, -13, 13, -10, 10, -7, 7, -4, 4, -1, 1],
                 int(np.ceil(len(dates)/6)))[:len(dates)]

# Create figure and plot a stem plot with the date
fig, ax = plt.subplots(figsize=(30, 12), constrained_layout=True)
#ax.set(title="Hawaii COVID Events and Dates in 2020", fontsize=12)
plt.suptitle('Hawaii COVID Events and Dates in 2020', fontsize=24)

markerline, stemline, baseline = ax.stem(dates, levels,
                                         linefmt="C3-", basefmt="k-",
                                         use_line_collection=True)

plt.setp(markerline, mec="k", mfc="w", zorder=3)

# Shift the markers to the baseline by replacing the y-data by zeros.
markerline.set_ydata(np.zeros(len(dates)))

# annotate lines
vert = np.array(['top', 'bottom'])[(levels > 0).astype(int)]
for d, l, r, va in zip(dates, levels, names, vert):
    ax.annotate(r, xy=(d, l), xytext=(-3, np.sign(l)*3),
                textcoords="offset points", va=va, ha="center")
                  
# format xaxis with 7 day intervals
ax.get_xaxis().set_major_locator(mdates.DayLocator(interval=7))
ax.get_xaxis().set_major_formatter(mdates.DateFormatter("%b %d"))
plt.setp(ax.get_xticklabels(), rotation=30, ha="right")

# remove y axis and spines
ax.get_yaxis().set_visible(False)
for spine in ["left", "top", "right"]:
    ax.spines[spine].set_visible(False)

ax.margins(y=0.1)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.dates as mdates
from datetime import datetime


# A list of COVID events and their dates
names = ['3/5: First emergency\nproclamation issued', 
         '3/6: First case', 
         '3/23: First death; Non-essential businesses,\n city and beach parks close. All city events\n canceled. Oahu stay-at-home order begins',
         '3/25: State and Maui County stay-at-home\norders begin; Public gathering\nspaces closed until Apr 30',
         '3/26: Mandatory 14-day quarantine\nfor travelers to Hawaii begins',
         '3/31: First death', 
         '4/1: Mandatory 14-day quarantine\nfor interisland travelers begins', 
       #  'Second death', 
        # 'Third death', 
        # 'Fourth death', 
         '4/13: Total cases surpasses 500,\n9 have died', 
         '4/17: State beaches close;\nDOE announces distance learning\nuntil end of school year', 
       #  'Daily new cases fall to single digits\nand continue for almost 2 months',
         '4/23: Face masks required in all business\nand public transportation in Honolulu',
         '4/25: State extends stay-at-home orders\nand the 14-day quarantine for\ntravelers until May 31',
         '5/5: Safer-at-home orders begin', 
         '5/7: Low-risk facilities reopen', 
         '5/15: Honolulu shopping centers, sport fields\n and courts, and drive-in services\nfor religious purposes reopen', 
         '5/16: Honolulu beaches reopen,\nwith social distancing', 
         '5/18: “Safer at Home” changes to\n“Acting with Care”. Medium-risk\nbusinesses can reopen in several weeks',
         '5/23: In-person spiritual services\nresume, with social distancing', 
         '5/31: Stay-at-home orders end', 
         '6/8: All state beaches and some\nstate parks reopen',
         '6/12: Daily cases reach double digits\nfirst time since Apr 18',
         '6/16: Interisland travelers no longer\nrequire self-quarantine',
         '6/19: Gyms, recreation areas, bars,\nand most other places reopen in Honolulu', 
         '6/20: Total cases surpass 800', 
         '6/30: 14-day quarantine for all travelers ends', 
         '7/23: Starts three record-setting days\nof case count: 55,60,73.\nMasks required in Honolulu gyms', 
         '8/1: Out-of-state visitors allowed to avoid\n14-day quarantine with\nnegative test results upon arrival', 
         '8/13: Daily cases of 355 sets new\nrecord; Marking 12+ days\nof 100+ daily new cases', 
         '8/18: Emergency Order 2020-24 Act With Care,\n No Social Gatherings enacted', 
         '8/26: Surge testing funded. 5000 people\ntested with 277 new cases',
         '8/27: New Stay-at-home order begins; DOE\nextends distance learning until Oct 2.\nSecond stay-at-home order begins',
         '8/31: Deadliest day since COVID with 7 deaths',         
         '9/15: Death rate hits 100',
         '9/24: Four-week-stay-at-home order\nends with a new tiered system\n for reopening']

dates = ['2020-03-05', 
         '2020-03-06',
         '2020-03-23', 
         '2020-03-25',
         '2020-03-26', 
         '2020-03-31',
         '2020-04-01', 
         #'2020-04-02',
         #'2020-04-03',
         #'2020-04-04', 
         '2020-04-13',
         '2020-04-17', 
        # '2020-04-19',
         '2020-04-23',
         '2020-04-25', 
         '2020-05-05',
         '2020-05-07',
         '2020-05-15', 
         '2020-05-16',
         '2020-05-18', 
         '2020-05-23',
         '2020-05-31', 
         '2020-06-08',
         '2020-06-12',
         '2020-06-16', 
         '2020-06-19',
         '2020-06-20', 
         '2020-06-30',
         '2020-07-23', 
         '2020-08-01',
         '2020-08-13',
         '2020-08-18', 
         '2020-08-26',
         '2020-08-27', 
         '2020-08-31',
         '2020-09-15',     
         '2020-09-24',
         ]
dates = [datetime.strptime(ii, "%Y-%m-%d") for ii in dates]

# Choose some nice levels
levels = np.tile([-16, 16, -13, 13, -10, 10, -7, 7, -4, 4, -1, 1],
                 int(np.ceil(len(dates)/6)))[:len(dates)]

# Create figure and plot a stem plot with the date
fig, ax = plt.subplots(figsize=(18, 8), constrained_layout=True)
#ax.set(title="Hawaii COVID Events and Dates in 2020", fontsize=12)
#plt.suptitle('Hawaii COVID Events and Dates in 2020', fontsize=24)

markerline, stemline, baseline = ax.stem(dates, levels,
                                         linefmt="C3-", basefmt="k-",
                                         use_line_collection=True)

plt.setp(markerline, mec="k", mfc="w", zorder=3)

# Shift the markers to the baseline by replacing the y-data by zeros.
markerline.set_ydata(np.zeros(len(dates)))

# annotate lines
vert = np.array(['top', 'bottom'])[(levels > 0).astype(int)]
for d, l, r, va in zip(dates, levels, names, vert):
    ax.annotate(r, xy=(d, l), xytext=(-3, np.sign(l)*3),
                textcoords="offset points", va=va, ha='center')
                  
# format xaxis with 7 day intervals
ax.get_xaxis().set_major_locator(mdates.DayLocator(interval=7))
ax.get_xaxis().set_major_formatter(mdates.DateFormatter("%b %d"))
plt.setp(ax.get_xticklabels(), rotation=30, ha="right")

# remove y axis and spines
ax.get_yaxis().set_visible(False)
for spine in ["left", "top", "right"]:
    ax.spines[spine].set_visible(False)

ax.margins(y=0.1)
plt.show()
